# %% [markdown]
# <a href="https://colab.research.google.com/github/igttsPro/DEV_ML_AI/blob/main/simple_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import ai
user_query = input("Your question: ")
response = ai.generate_text(prompt=user_query)
response
# Out:
# Your question: When did the Ukraine with Russia start?
# ...
